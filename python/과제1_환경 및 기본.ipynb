# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: o

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (4)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('윤동건',end=' ')
print('2000/01/27')
# Out:
# 윤동건 2000/01/27

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('안녕하세요. 같이 파이썬 실습해요.')
print('\t앞에 공간을 띄우세요.')
print('\t\t두번을 띄워보세요.')
# Out:
# 안녕하세요. 같이 파이썬 실습해요.
# 	앞에 공간을 띄우세요.
# 		두번을 띄워보세요.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (3)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = '윤동건'
print(f'안녕하세요, {name}님!')
# Out:
# 안녕하세요, 윤동건님!

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(f'5와 10의 합은 {5+10}입니다.')
# Out:
# 5와 10의 합은 15입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: (2)
